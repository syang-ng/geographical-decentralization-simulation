# %%
from mesa import Agent, Model
from mesa.datacollection import DataCollector
from scipy.stats import poisson, norm

import random
import matplotlib.pyplot as plt
import numpy as np
import math
from abc import ABC, abstractmethod

# %%
# Constants
SLOT_DURATION_MS = 12000  # Duration of an Ethereum slot in milliseconds
TIME_GRANULARITY_MS = 100 # Simulation time step in milliseconds
ATTESTATION_TIME_MS = 4000 # Default time for Attesters to attest (can be varied per Attester)

# Network Latency Model Parameters: latency = BASE_NETWORK_LATENCY_MS + (distance_ratio * MAX_ADDITIONAL_NETWORK_LATENCY_MS)
BASE_NETWORK_LATENCY_MS = 50  # Minimum network latency regardless of distance
MAX_ADDITIONAL_NETWORK_LATENCY_MS = 2000 # Max additional latency for max distance on sphere

# MEV yield model (simulating Builder bids increasing over time)
## The number is set randomly now.
BASE_MEV_AMOUNT = 0.2  # Initial MEV in ETH
MEV_INCREASE_PER_SECOND = 0.08 # MEV increase per second (ETH/sec)

# --- Spatial Classes ---

class Space(ABC):
    """
    Abstract base class defining the interface for a 'space'
    where nodes can live. Subclasses must implement:
      - sample_point()
      - distance(p1, p2)
    """

    @abstractmethod
    def sample_point(self):
        """Samples a random point within the space."""
        pass

    @abstractmethod
    def distance(self, p1, p2):
        """Calculates the distance between two points in the space."""
        pass

    @abstractmethod
    def get_area(self):
        """Returns the total 'area' or size of the space."""
        pass

    @abstractmethod
    def get_max_dist(self):
        """Returns the maximum possible distance between any two points in the space."""
        pass

class SphericalSpace(Space):
    """
    Sample points on (or near) the unit sphere.
    distance() returns geodesic distance (great-circle distance).
    """
    def sample_point(self):
        """Samples a random point on the unit sphere (x, y, z)."""
        # Sample (x, y, z) from Normal(0, 1),
        # then normalize to lie on the unit sphere.
        while True:
            x = random.gauss(0, 1)
            y = random.gauss(0, 1)
            z = random.gauss(0, 1)
            r2 = x*x + y*y + z*z
            if r2 > 1e-12: # Avoid division by zero for very small magnitudes
                scale = 1.0 / math.sqrt(r2)
                return (x*scale, y*scale, z*scale)

    def distance(self, p1, p2):
        """
        Calculates the geodesic distance between two points on a unit sphere.
        Distance = arc length = arccos(dot(p1,p2)).
        """
        dotp = p1[0]*p2[0] + p1[1]*p2[1] + p1[2]*p2[2]
        # Numerical safety clamp for dot product to be within [-1, 1] due to floating point inaccuracies
        dotp = max(-1.0, min(1.0, dotp))
        return math.acos(dotp)
    
    def get_area(self):
        """Returns the surface area of a unit sphere."""
        return 4 * np.pi

    def get_max_dist(self):
        """Returns the maximum possible geodesic distance on a unit sphere (half circumference)."""
        return np.pi # Half the circumference of a unit circle (pi * diameter = pi * 2 * radius = 2*pi * 1 / 2 = pi)
    
def init_distance_matrix(positions, space):
    """
    Build the initial distance matrix for all node pairs.
    Returns a 2D list (or NumPy array) of shape (n, n).
    """
    n = len(positions)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            d = space.distance(positions[i], positions[j])
            dist_matrix[i][j] = d
            dist_matrix[j][i] = d # Symmetric matrix
    return dist_matrix

# --- Validator Agent Class Definition ---

class ValidatorAgent:
    def __init__(self, validator_id):
        self.validator_id = validator_id
        self.position = None # (x, y, z) coordinates in the space
        self.role = "none"  # "proposer" or "attester"
        self.network_latency_to_proposer = -1 # Latency for block from Proposer to THIS validator

        self.reset_for_new_slot()

        # Specific attributes for Proposer role
        self.proposer_strategy = None 
        # For random delay proposer strategy
        self.random_propose_time = -1 
        self.attestation_time_ms = ATTESTATION_TIME_MS # Default attestation time for Attesters


    def reset_for_new_slot(self):
        """Resets the validator's ephemeral state for a new slot."""
        self.has_proposed_block = False
        self.proposed_time_ms = -1
        self.mev_captured = 0.0 # MEV captured if supermajority is achieved
        self.block_arrival_at_self_ms = -1 # Time the Proposer's block arrives at this validator
        self.has_attested = False
        self.attested_to_proposer_block = False # True if this attester made a valid attestation for Proposer's block
        self.role = "none"

    def set_proposer_role(self):
        """Sets this validator as the Proposer for the current slot."""
        self.role = "proposer"

    def set_proposer_strategy(self, strategy):
        """Sets the Proposer's strategy for block proposal."""
        self.proposer_strategy = strategy
        # Initialize random propose time if using random strategy
        if strategy["type"] == "random_delay":
            self.random_propose_time = random.randint(strategy["min_delay_ms"], strategy["max_delay_ms"])

    def set_attester_role(self, current_proposer_id, distance_matrix, space_max_dist):
        """Sets this validator as an Attester for the current slot and calculates its specific latency."""
        self.role = "attester"
        
        # Calculate specific network latency based on distance to the current proposer
        distance = distance_matrix[self.validator_id][current_proposer_id]
        self.network_latency_to_proposer = BASE_NETWORK_LATENCY_MS + \
                                           (distance / space_max_dist) * MAX_ADDITIONAL_NETWORK_LATENCY_MS

    def get_current_mev_offer(self, current_slot_time_ms):
        """Simulates the current MEV bid offered by Relays."""
        time_in_seconds = current_slot_time_ms / 1000
        return max(BASE_MEV_AMOUNT, BASE_MEV_AMOUNT + time_in_seconds * MEV_INCREASE_PER_SECOND)

    def decide_and_propose(self, current_slot_time_ms):
        """
        Proposer (this validator) decides whether to propose a block based on its strategy.
        Returns (should_propose, mev_offer_if_proposing)
        """
        if self.role != "proposer" or self.has_proposed_block:
            return False, 0.0

        mev_offer = self.get_current_mev_offer(current_slot_time_ms)

        if self.proposer_strategy["type"] == "fixed_delay":
            if current_slot_time_ms >= self.proposer_strategy["delay_ms"]:
                return True, mev_offer
        elif self.proposer_strategy["type"] == "threshold_and_max_delay":
            if mev_offer >= self.proposer_strategy["mev_threshold"] or \
               current_slot_time_ms >= self.proposer_strategy["max_delay_ms"]:
                return True, mev_offer
        elif self.proposer_strategy["type"] == "random_delay":
            if self.random_propose_time == -1: # Should ideally be set by set_proposer_role, but as a fallback
                self.random_propose_time = random.randint(self.proposer_strategy["min_delay_ms"], self.proposer_strategy["max_delay_ms"])
            if current_slot_time_ms >= self.random_propose_time:
                return True, mev_offer
        
        return False, 0.0

    def propose_block(self, current_slot_time_ms, mev_offer):
        """Executes the block proposal action for the Proposer."""
        self.has_proposed_block = True
        self.proposed_time_ms = current_slot_time_ms
        self.mev_captured_potential = mev_offer # Store potential MEV before supermajority check
        # print(f"  Validator {self.validator_id} (Proposer) proposed block at {current_slot_time_ms}ms, MEV: {mev_offer:.4f} ETH.")

    def receive_block(self, proposed_time_ms):
        """Simulates this validator receiving the block from the Proposer."""
        # Calculate time when block arrives at THIS specific validator
        self.block_arrival_at_self_ms = proposed_time_ms + self.network_latency_to_proposer

    def decide_and_attest(self, current_slot_time_ms, proposer_proposed_time_ms):
        """
        Attester (this validator) decides whether to attest to the Proposer's block.
        proposer_proposed_time_ms: The time the Proposer actually broadcasted the block.
        """
        if self.role != "attester" or self.has_attested:
            return

        # Calculate this attester's specific block arrival time
        block_arrival_at_this_attester_ms = proposer_proposed_time_ms + self.network_latency_to_proposer

        if current_slot_time_ms >= self.attestation_time_ms:
            # Check if Proposer's block arrived before or at this Attester's attestation time
            if proposer_proposed_time_ms != -1 and \
               block_arrival_at_this_attester_ms <= self.attestation_time_ms:
                self.attested_to_proposer_block = True
                # print(f"    Validator {self.validator_id} (Attester) at {current_slot_time_ms}ms made valid attestation.")
            else:
                self.attested_to_proposer_block = False
                # print(f"    Validator {self.validator_id} (Attester) at {current_slot_time_ms}ms attested to blank or missed.")
            self.has_attested = True

# %%
# --- Main Simulation Loop ---
def run_multi_validator_simulation(num_validators, proposer_strategies_pool, num_slots=100):
    # Initialize the space and assign positions to all validators
    space = SphericalSpace()
    validators = [ValidatorAgent(i) for i in range(num_validators)]
    for validator in validators:
        # position
        validator.position = space.sample_point()
        # strategy
        proposer_strategy = random.choice(proposer_strategies_pool)
        validator.set_proposer_strategy(proposer_strategy)
    
    # Pre-calculate distance matrix for all validator pairs
    validator_positions = [v.position for v in validators]
    distance_matrix = init_distance_matrix(validator_positions, space)
    space_max_dist = space.get_max_dist() # Maximum possible distance in our spherical space

    total_mev_earned = 0.0
    total_successful_attestations = 0 # Sum of successful attestations across all slots
    total_attesters_count = num_slots * (num_validators - 1) # Total possible attestations across all slots
    proposed_block_times = [] # Records the time of block proposal for each slot
    supermajority_met_slots = 0 # Counter for slots where supermajority was achieved

    print(f"\n--- Simulation Started: {num_validators} Validators ---")
    print(f"Proposer will randomly choose from {len(proposer_strategies_pool)} strategies:")
    for i, strategy in enumerate(proposer_strategies_pool):
        print(f"  Strategy {i+1}: Type={strategy['type']}", end="")
        if "delay_ms" in strategy: print(f", Delay={strategy['delay_ms']}ms", end="")
        if "mev_threshold" in strategy: print(f", Threshold={strategy['mev_threshold']:.4f} ETH, Max Delay={strategy['max_delay_ms']}ms", end="")
        if "min_delay_ms" in strategy: print(f", Random Range={strategy['min_delay_ms']}-{strategy['max_delay_ms']}ms", end="")
        print()
    print(f"Attester Default Attestation Time: {ATTESTATION_TIME_MS}ms.")
    print(f"Network Latency Model: {BASE_NETWORK_LATENCY_MS}ms + (distance_ratio * {MAX_ADDITIONAL_NETWORK_LATENCY_MS}ms)\n")

    for slot_idx in range(num_slots):
        print(f"\n--- Slot {slot_idx + 1} ---")
        
        # Reset all validators for the new slot
        for validator in validators:
            validator.reset_for_new_slot()

        # Randomly select a Proposer for this slot
        proposer_agent = random.choice(validators)
        proposer_agent.set_proposer_role() # Set this validator as the Proposer
        
        # Set remaining validators as Attesters and calculate their specific latencies
        attesters = [v for v in validators if v.validator_id != proposer_agent.validator_id]
        for attester in attesters:
            attester.set_attester_role(proposer_agent.validator_id, distance_matrix, space_max_dist)
        
        current_proposer_proposed_time = -1 # Tracks when the actual Proposer proposes their block
        slot_potential_mev = 0.0 # Potential MEV for this slot, before supermajority check

        for current_slot_time_ms in range(0, SLOT_DURATION_MS, TIME_GRANULARITY_MS):
            # Proposer's decision and proposal
            should_propose, mev_offer = proposer_agent.decide_and_propose(current_slot_time_ms)
            if should_propose:
                proposer_agent.propose_block(current_slot_time_ms, mev_offer)
                current_proposer_proposed_time = proposer_agent.proposed_time_ms
                slot_potential_mev = mev_offer # Store potential MEV for this slot
                # Once proposed, Proposer doesn't propose again in this slot

            # Attesters' decisions and attestations
            # Each attester decides based on its own specific network latency to the proposer
            for attester in attesters:
                attester.decide_and_attest(
                    current_slot_time_ms, 
                    current_proposer_proposed_time
                )

            # Check if all relevant actions for this slot are done (Proposer proposed & all Attesters attested)
            if (proposer_agent.has_proposed_block and all(a.has_attested for a in attesters)) or \
               (all(a.has_attested for a in attesters)):
                break
            
        # End of slot statistics and REWARD CALCULATION based on SUPERMAJORITY
        if proposer_agent.has_proposed_block:
            proposed_block_times.append(proposer_agent.proposed_time_ms)
            
            slot_successful_attestations = sum(1 for a in attesters if a.attested_to_proposer_block)
            
            # --- SUPERMAJORITY REWARD LOGIC ---
            required_attesters_for_supermajority = math.ceil((2/3) * len(attesters))
            
            if slot_successful_attestations >= required_attesters_for_supermajority:
                proposer_agent.mev_captured = slot_potential_mev # Proposer gets full MEV + consensus reward
                total_mev_earned += proposer_agent.mev_captured
                supermajority_met_slots += 1
                print(f"Slot {slot_idx + 1} SUCCESS: Proposer earned {proposer_agent.mev_captured:.4f} ETH. Attestations: {slot_successful_attestations}/{len(attesters)} (Needed {required_attesters_for_supermajority}).")
            else:
                proposer_agent.mev_captured = 0.0 # Proposer gets zero reward if supermajority not met
                print(f"Slot {slot_idx + 1} FAILED (NO SUPERMAJORITY): Proposer earned {proposer_agent.mev_captured:.4f} ETH. Attestations: {slot_successful_attestations}/{len(attesters)} (Needed {required_attesters_for_supermajority}).")
            # --- END SUPERMAJORITY REWARD LOGIC ---

            total_successful_attestations += slot_successful_attestations

    avg_mev_per_slot = total_mev_earned / num_slots
    avg_attestation_rate = (total_successful_attestations / total_attesters_count) * 100 if total_attesters_count > 0 else 0
    supermajority_success_rate = (supermajority_met_slots / num_slots) * 100

    print(f"\n--- Simulation Results ---")
    print(f"Total Slots Simulated: {num_slots}")
    print(f"Average MEV Earned Per Slot (by Proposer): {avg_mev_per_slot:.4f} ETH")
    print(f"Average Effective Attestation Rate (across all Attesters): {avg_attestation_rate:.2f}%")
    print(f"Supermajority Attestation Success Rate: {supermajority_success_rate:.2f}%")

    return avg_mev_per_slot, avg_attestation_rate, supermajority_success_rate, proposed_block_times

# %%
# --- Simulation Execution ---
random.seed(0x06511)  # For reproducibility
np.random.seed(0x06511)  # For reproducibility in NumPy operations
# --- Define the Pool of Proposer Strategies ---
NUM_VALIDATORS = 100 # Example: Simulate 100 validators

# This pool contains all the different strategies that the Proposer can randomly choose from
all_proposer_strategies = [
    {"type": "fixed_delay", "delay_ms": 500}, # Strategy 1: Fixed delay at 0.5 seconds
    {"type": "fixed_delay", "delay_ms": 1500}, # Strategy 2: Faster fixed delay at 1.5 second
    {"type": "threshold_and_max_delay", "mev_threshold": 0.3, "max_delay_ms": 2500}, # Strategy 3: Threshold 0.4 ETH or max 2.5s delay
    {"type": "random_delay", "min_delay_ms": 1000, "max_delay_ms": 3000}, # Strategy 4: Random delay between 1s and 3s
    {"type": "threshold_and_max_delay", "mev_threshold": 0.4, "max_delay_ms": 3000}, # Strategy 5: More aggressive threshold 0.5 ETH or max 3s delay
]

# Run a single large simulation where the Proposer randomly picks a strategy each slot
avg_mev_overall, avg_attestation_rate, supermajority_success_rate, times_overall = \
    run_multi_validator_simulation(NUM_VALIDATORS, all_proposer_strategies, num_slots=1000) # Increased slots for better averages
# Out:
# --- Simulation Started: 100 Validators ---
# Proposer will randomly choose from 5 strategies:
#   Strategy 1: Type=fixed_delay, Delay=500ms
#   Strategy 2: Type=fixed_delay, Delay=1500ms
#   Strategy 3: Type=threshold_and_max_delay, Threshold=0.3000 ETH, Max Delay=2500ms
#   Strategy 4: Type=random_delay, Random Range=1000-3000ms
#   Strategy 5: Type=threshold_and_max_delay, Threshold=0.4000 ETH, Max Delay=3000ms
# Attester Default Attestation Time: 4000ms.
# Network Latency Model: 50ms + (distance_ratio * 2000ms)
#
#
# --- Slot 1 ---
# Slot 1 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 2 ---
# Slot 2 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 3 ---
# Slot 3 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 4 ---
# Slot 4 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 5 ---
# Slot 5 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 6 ---
# Slot 6 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 7 ---
# Slot 7 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 8 ---
# Slot 8 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 9 ---
# Slot 9 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 10 ---
# Slot 10 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 11 ---
# Slot 11 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 12 ---
# Slot 12 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 13 ---
# Slot 13 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 14 ---
# Slot 14 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 15 ---
# Slot 15 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 16 ---
# Slot 16 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 17 ---
# Slot 17 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 18 ---
# Slot 18 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 19 ---
# Slot 19 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 20 ---
# Slot 20 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 21 ---
# Slot 21 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 22 ---
# Slot 22 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 23 ---
# Slot 23 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 24 ---
# Slot 24 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 25 ---
# Slot 25 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 26 ---
# Slot 26 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 27 ---
# Slot 27 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 28 ---
# Slot 28 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 89/99 (Needed 66).
#
# --- Slot 29 ---
# Slot 29 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 30 ---
# Slot 30 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 31 ---
# Slot 31 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 32 ---
# Slot 32 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 33 ---
# Slot 33 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 86/99 (Needed 66).
#
# --- Slot 34 ---
# Slot 34 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 35 ---
# Slot 35 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 36 ---
# Slot 36 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 37 ---
# Slot 37 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 38 ---
# Slot 38 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 39 ---
# Slot 39 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 40 ---
# Slot 40 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 41 ---
# Slot 41 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 42 ---
# Slot 42 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 43 ---
# Slot 43 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 44 ---
# Slot 44 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 45 ---
# Slot 45 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 46 ---
# Slot 46 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 47 ---
# Slot 47 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 48 ---
# Slot 48 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 49 ---
# Slot 49 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 50 ---
# Slot 50 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 51 ---
# Slot 51 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 52 ---
# Slot 52 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 53 ---
# Slot 53 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 54 ---
# Slot 54 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 86/99 (Needed 66).
#
# --- Slot 55 ---
# Slot 55 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 56 ---
# Slot 56 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 57 ---
# Slot 57 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 58 ---
# Slot 58 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 59 ---
# Slot 59 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 60 ---
# Slot 60 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 61 ---
# Slot 61 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 62 ---
# Slot 62 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 63 ---
# Slot 63 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 64 ---
# Slot 64 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 65 ---
# Slot 65 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 66 ---
# Slot 66 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 86/99 (Needed 66).
#
# --- Slot 67 ---
# Slot 67 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 68 ---
# Slot 68 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 69 ---
# Slot 69 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 70 ---
# Slot 70 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 71 ---
# Slot 71 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 72 ---
# Slot 72 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 73 ---
# Slot 73 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 74 ---
# Slot 74 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 75 ---
# Slot 75 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 76 ---
# Slot 76 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 77 ---
# Slot 77 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 78 ---
# Slot 78 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 79 ---
# Slot 79 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 80 ---
# Slot 80 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 81 ---
# Slot 81 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 82 ---
# Slot 82 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 83 ---
# Slot 83 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 84 ---
# Slot 84 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 85 ---
# Slot 85 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 86 ---
# Slot 86 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 87 ---
# Slot 87 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 88 ---
# Slot 88 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 89 ---
# Slot 89 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 90 ---
# Slot 90 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 91 ---
# Slot 91 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 92 ---
# Slot 92 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 93 ---
# Slot 93 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 94 ---
# Slot 94 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 95 ---
# Slot 95 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 96 ---
# Slot 96 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 97 ---
# Slot 97 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 98 ---
# Slot 98 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 99 ---
# Slot 99 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 100 ---
# Slot 100 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 101 ---
# Slot 101 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 102 ---
# Slot 102 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 103 ---
# Slot 103 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 104 ---
# Slot 104 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 105 ---
# Slot 105 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 81/99 (Needed 66).
#
# --- Slot 106 ---
# Slot 106 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 107 ---
# Slot 107 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 108 ---
# Slot 108 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 109 ---
# Slot 109 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 110 ---
# Slot 110 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 111 ---
# Slot 111 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 112 ---
# Slot 112 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 113 ---
# Slot 113 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 114 ---
# Slot 114 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 115 ---
# Slot 115 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 116 ---
# Slot 116 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 117 ---
# Slot 117 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 118 ---
# Slot 118 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 119 ---
# Slot 119 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 120 ---
# Slot 120 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 121 ---
# Slot 121 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 122 ---
# Slot 122 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 123 ---
# Slot 123 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 124 ---
# Slot 124 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 125 ---
# Slot 125 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 91/99 (Needed 66).
#
# --- Slot 126 ---
# Slot 126 SUCCESS: Proposer earned 0.3840 ETH. Attestations: 90/99 (Needed 66).
#
# --- Slot 127 ---
# Slot 127 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 128 ---
# Slot 128 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 129 ---
# Slot 129 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 130 ---
# Slot 130 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 131 ---
# Slot 131 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 132 ---
# Slot 132 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 133 ---
# Slot 133 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 134 ---
# Slot 134 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 135 ---
# Slot 135 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 136 ---
# Slot 136 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 137 ---
# Slot 137 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 138 ---
# Slot 138 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 139 ---
# Slot 139 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 140 ---
# Slot 140 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 141 ---
# Slot 141 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 142 ---
# Slot 142 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 143 ---
# Slot 143 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 144 ---
# Slot 144 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 145 ---
# Slot 145 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 146 ---
# Slot 146 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 147 ---
# Slot 147 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 148 ---
# Slot 148 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 149 ---
# Slot 149 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 150 ---
# Slot 150 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 151 ---
# Slot 151 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 152 ---
# Slot 152 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 153 ---
# Slot 153 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 154 ---
# Slot 154 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 155 ---
# Slot 155 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 156 ---
# Slot 156 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 157 ---
# Slot 157 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 158 ---
# Slot 158 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 159 ---
# Slot 159 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 160 ---
# Slot 160 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 161 ---
# Slot 161 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 162 ---
# Slot 162 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 163 ---
# Slot 163 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 164 ---
# Slot 164 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 88/99 (Needed 66).
#
# --- Slot 165 ---
# Slot 165 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 166 ---
# Slot 166 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 167 ---
# Slot 167 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 168 ---
# Slot 168 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 169 ---
# Slot 169 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 81/99 (Needed 66).
#
# --- Slot 170 ---
# Slot 170 SUCCESS: Proposer earned 0.3840 ETH. Attestations: 90/99 (Needed 66).
#
# --- Slot 171 ---
# Slot 171 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 172 ---
# Slot 172 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 173 ---
# Slot 173 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 174 ---
# Slot 174 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 175 ---
# Slot 175 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 91/99 (Needed 66).
#
# --- Slot 176 ---
# Slot 176 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 177 ---
# Slot 177 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 178 ---
# Slot 178 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 179 ---
# Slot 179 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 180 ---
# Slot 180 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 181 ---
# Slot 181 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 182 ---
# Slot 182 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 183 ---
# Slot 183 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 184 ---
# Slot 184 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 185 ---
# Slot 185 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 186 ---
# Slot 186 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 187 ---
# Slot 187 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 188 ---
# Slot 188 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 189 ---
# Slot 189 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 190 ---
# Slot 190 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 191 ---
# Slot 191 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 192 ---
# Slot 192 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 193 ---
# Slot 193 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 194 ---
# Slot 194 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 195 ---
# Slot 195 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 196 ---
# Slot 196 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 197 ---
# Slot 197 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 198 ---
# Slot 198 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 199 ---
# Slot 199 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 200 ---
# Slot 200 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 201 ---
# Slot 201 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 202 ---
# Slot 202 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 203 ---
# Slot 203 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 204 ---
# Slot 204 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 205 ---
# Slot 205 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 206 ---
# Slot 206 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 207 ---
# Slot 207 SUCCESS: Proposer earned 0.3840 ETH. Attestations: 90/99 (Needed 66).
#
# --- Slot 208 ---
# Slot 208 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 209 ---
# Slot 209 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 89/99 (Needed 66).
#
# --- Slot 210 ---
# Slot 210 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 211 ---
# Slot 211 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 212 ---
# Slot 212 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 213 ---
# Slot 213 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 214 ---
# Slot 214 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 215 ---
# Slot 215 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 216 ---
# Slot 216 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 217 ---
# Slot 217 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 218 ---
# Slot 218 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 219 ---
# Slot 219 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 220 ---
# Slot 220 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 221 ---
# Slot 221 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 222 ---
# Slot 222 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 223 ---
# Slot 223 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 224 ---
# Slot 224 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 225 ---
# Slot 225 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 226 ---
# Slot 226 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 227 ---
# Slot 227 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 228 ---
# Slot 228 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 229 ---
# Slot 229 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 230 ---
# Slot 230 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 231 ---
# Slot 231 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 232 ---
# Slot 232 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 233 ---
# Slot 233 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 234 ---
# Slot 234 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 235 ---
# Slot 235 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 236 ---
# Slot 236 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 237 ---
# Slot 237 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 238 ---
# Slot 238 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 239 ---
# Slot 239 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 240 ---
# Slot 240 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 241 ---
# Slot 241 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 242 ---
# Slot 242 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 243 ---
# Slot 243 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 244 ---
# Slot 244 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 245 ---
# Slot 245 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 246 ---
# Slot 246 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 247 ---
# Slot 247 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 248 ---
# Slot 248 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 249 ---
# Slot 249 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 250 ---
# Slot 250 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 251 ---
# Slot 251 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 252 ---
# Slot 252 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 253 ---
# Slot 253 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 254 ---
# Slot 254 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 255 ---
# Slot 255 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 256 ---
# Slot 256 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 257 ---
# Slot 257 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 258 ---
# Slot 258 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 259 ---
# Slot 259 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 260 ---
# Slot 260 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 261 ---
# Slot 261 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 262 ---
# Slot 262 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 263 ---
# Slot 263 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 264 ---
# Slot 264 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 88/99 (Needed 66).
#
# --- Slot 265 ---
# Slot 265 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 266 ---
# Slot 266 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 267 ---
# Slot 267 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 268 ---
# Slot 268 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 269 ---
# Slot 269 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 270 ---
# Slot 270 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 271 ---
# Slot 271 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 272 ---
# Slot 272 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 273 ---
# Slot 273 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 274 ---
# Slot 274 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 275 ---
# Slot 275 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 276 ---
# Slot 276 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 277 ---
# Slot 277 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 278 ---
# Slot 278 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 279 ---
# Slot 279 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 280 ---
# Slot 280 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 281 ---
# Slot 281 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 282 ---
# Slot 282 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 283 ---
# Slot 283 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 284 ---
# Slot 284 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 285 ---
# Slot 285 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 286 ---
# Slot 286 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 287 ---
# Slot 287 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 288 ---
# Slot 288 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 289 ---
# Slot 289 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 290 ---
# Slot 290 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 291 ---
# Slot 291 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 292 ---
# Slot 292 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 293 ---
# Slot 293 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 294 ---
# Slot 294 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 295 ---
# Slot 295 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 296 ---
# Slot 296 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 297 ---
# Slot 297 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 298 ---
# Slot 298 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 299 ---
# Slot 299 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 300 ---
# Slot 300 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 301 ---
# Slot 301 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 302 ---
# Slot 302 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 303 ---
# Slot 303 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 304 ---
# Slot 304 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 305 ---
# Slot 305 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 306 ---
# Slot 306 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 307 ---
# Slot 307 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 308 ---
# Slot 308 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 309 ---
# Slot 309 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 310 ---
# Slot 310 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 311 ---
# Slot 311 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 312 ---
# Slot 312 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 313 ---
# Slot 313 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 314 ---
# Slot 314 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 315 ---
# Slot 315 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 316 ---
# Slot 316 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 317 ---
# Slot 317 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 318 ---
# Slot 318 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 319 ---
# Slot 319 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 320 ---
# Slot 320 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 88/99 (Needed 66).
#
# --- Slot 321 ---
# Slot 321 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 322 ---
# Slot 322 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 323 ---
# Slot 323 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 324 ---
# Slot 324 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 325 ---
# Slot 325 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 326 ---
# Slot 326 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 327 ---
# Slot 327 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 328 ---
# Slot 328 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 329 ---
# Slot 329 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 330 ---
# Slot 330 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 331 ---
# Slot 331 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 332 ---
# Slot 332 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 333 ---
# Slot 333 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 334 ---
# Slot 334 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 335 ---
# Slot 335 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 336 ---
# Slot 336 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 337 ---
# Slot 337 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 338 ---
# Slot 338 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 339 ---
# Slot 339 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 340 ---
# Slot 340 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 341 ---
# Slot 341 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 342 ---
# Slot 342 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 343 ---
# Slot 343 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 344 ---
# Slot 344 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 345 ---
# Slot 345 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 346 ---
# Slot 346 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 347 ---
# Slot 347 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 348 ---
# Slot 348 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 349 ---
# Slot 349 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 350 ---
# Slot 350 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 351 ---
# Slot 351 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 352 ---
# Slot 352 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 353 ---
# Slot 353 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 354 ---
# Slot 354 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 355 ---
# Slot 355 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 356 ---
# Slot 356 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 357 ---
# Slot 357 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 358 ---
# Slot 358 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 359 ---
# Slot 359 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 360 ---
# Slot 360 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 361 ---
# Slot 361 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 362 ---
# Slot 362 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 363 ---
# Slot 363 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 364 ---
# Slot 364 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 365 ---
# Slot 365 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 366 ---
# Slot 366 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 367 ---
# Slot 367 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 368 ---
# Slot 368 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 369 ---
# Slot 369 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 370 ---
# Slot 370 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 371 ---
# Slot 371 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 372 ---
# Slot 372 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 373 ---
# Slot 373 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 374 ---
# Slot 374 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 375 ---
# Slot 375 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 376 ---
# Slot 376 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 377 ---
# Slot 377 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 378 ---
# Slot 378 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 379 ---
# Slot 379 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 380 ---
# Slot 380 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 381 ---
# Slot 381 SUCCESS: Proposer earned 0.3840 ETH. Attestations: 90/99 (Needed 66).
#
# --- Slot 382 ---
# Slot 382 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 383 ---
# Slot 383 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 384 ---
# Slot 384 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 385 ---
# Slot 385 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 386 ---
# Slot 386 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 387 ---
# Slot 387 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 388 ---
# Slot 388 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 389 ---
# Slot 389 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 390 ---
# Slot 390 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 391 ---
# Slot 391 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 392 ---
# Slot 392 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 393 ---
# Slot 393 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 394 ---
# Slot 394 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 395 ---
# Slot 395 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 396 ---
# Slot 396 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 397 ---
# Slot 397 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 398 ---
# Slot 398 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 399 ---
# Slot 399 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 400 ---
# Slot 400 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 401 ---
# Slot 401 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 402 ---
# Slot 402 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 403 ---
# Slot 403 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 404 ---
# Slot 404 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 405 ---
# Slot 405 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 406 ---
# Slot 406 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 407 ---
# Slot 407 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 408 ---
# Slot 408 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 409 ---
# Slot 409 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 410 ---
# Slot 410 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 411 ---
# Slot 411 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 412 ---
# Slot 412 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 413 ---
# Slot 413 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 414 ---
# Slot 414 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 415 ---
# Slot 415 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 416 ---
# Slot 416 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 417 ---
# Slot 417 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 418 ---
# Slot 418 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 419 ---
# Slot 419 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 420 ---
# Slot 420 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 421 ---
# Slot 421 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 422 ---
# Slot 422 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 423 ---
# Slot 423 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 424 ---
# Slot 424 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 425 ---
# Slot 425 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 426 ---
# Slot 426 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 427 ---
# Slot 427 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 428 ---
# Slot 428 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 429 ---
# Slot 429 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 430 ---
# Slot 430 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 431 ---
# Slot 431 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 432 ---
# Slot 432 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 433 ---
# Slot 433 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 434 ---
# Slot 434 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 435 ---
# Slot 435 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 436 ---
# Slot 436 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 437 ---
# Slot 437 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 438 ---
# Slot 438 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 439 ---
# Slot 439 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 440 ---
# Slot 440 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 441 ---
# Slot 441 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 442 ---
# Slot 442 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 443 ---
# Slot 443 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 444 ---
# Slot 444 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 445 ---
# Slot 445 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 446 ---
# Slot 446 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 447 ---
# Slot 447 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 448 ---
# Slot 448 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 449 ---
# Slot 449 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 450 ---
# Slot 450 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 451 ---
# Slot 451 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 452 ---
# Slot 452 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 453 ---
# Slot 453 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 454 ---
# Slot 454 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 455 ---
# Slot 455 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 456 ---
# Slot 456 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 457 ---
# Slot 457 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 458 ---
# Slot 458 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 459 ---
# Slot 459 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 460 ---
# Slot 460 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 461 ---
# Slot 461 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 462 ---
# Slot 462 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 463 ---
# Slot 463 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 464 ---
# Slot 464 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 465 ---
# Slot 465 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 466 ---
# Slot 466 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 467 ---
# Slot 467 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 468 ---
# Slot 468 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 469 ---
# Slot 469 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 470 ---
# Slot 470 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 471 ---
# Slot 471 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 472 ---
# Slot 472 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 473 ---
# Slot 473 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 474 ---
# Slot 474 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 475 ---
# Slot 475 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 476 ---
# Slot 476 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 477 ---
# Slot 477 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 478 ---
# Slot 478 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 479 ---
# Slot 479 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 480 ---
# Slot 480 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 481 ---
# Slot 481 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 482 ---
# Slot 482 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 483 ---
# Slot 483 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 484 ---
# Slot 484 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 485 ---
# Slot 485 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 486 ---
# Slot 486 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 487 ---
# Slot 487 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 488 ---
# Slot 488 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 489 ---
# Slot 489 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 490 ---
# Slot 490 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 491 ---
# ...
# Slot 839 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 840 ---
# Slot 840 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 841 ---
# Slot 841 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 842 ---
# Slot 842 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 843 ---
# Slot 843 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 844 ---
# Slot 844 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 845 ---
# Slot 845 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 846 ---
# Slot 846 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 847 ---
# Slot 847 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 848 ---
# Slot 848 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 849 ---
# Slot 849 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 850 ---
# Slot 850 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 851 ---
# Slot 851 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 81/99 (Needed 66).
#
# --- Slot 852 ---
# Slot 852 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 853 ---
# Slot 853 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 854 ---
# Slot 854 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 855 ---
# Slot 855 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 856 ---
# Slot 856 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 857 ---
# Slot 857 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 858 ---
# Slot 858 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 91/99 (Needed 66).
#
# --- Slot 859 ---
# Slot 859 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 860 ---
# Slot 860 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 861 ---
# Slot 861 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 862 ---
# Slot 862 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 863 ---
# Slot 863 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 864 ---
# Slot 864 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 865 ---
# Slot 865 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 866 ---
# Slot 866 SUCCESS: Proposer earned 0.3520 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 867 ---
# Slot 867 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 868 ---
# Slot 868 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 869 ---
# Slot 869 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 870 ---
# Slot 870 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 871 ---
# Slot 871 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 872 ---
# Slot 872 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 873 ---
# Slot 873 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 874 ---
# Slot 874 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 875 ---
# Slot 875 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 876 ---
# Slot 876 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 877 ---
# Slot 877 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 878 ---
# Slot 878 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 879 ---
# Slot 879 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 880 ---
# Slot 880 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 881 ---
# Slot 881 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 882 ---
# Slot 882 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 883 ---
# Slot 883 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 85/99 (Needed 66).
#
# --- Slot 884 ---
# Slot 884 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 885 ---
# Slot 885 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 886 ---
# Slot 886 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 887 ---
# Slot 887 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 888 ---
# Slot 888 SUCCESS: Proposer earned 0.3600 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 889 ---
# Slot 889 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 890 ---
# Slot 890 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 891 ---
# Slot 891 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 892 ---
# Slot 892 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 893 ---
# Slot 893 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 894 ---
# Slot 894 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 895 ---
# Slot 895 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 896 ---
# Slot 896 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 897 ---
# Slot 897 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 898 ---
# Slot 898 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 899 ---
# Slot 899 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 900 ---
# Slot 900 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 901 ---
# Slot 901 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 902 ---
# Slot 902 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 903 ---
# Slot 903 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 904 ---
# Slot 904 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 905 ---
# Slot 905 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 86/99 (Needed 66).
#
# --- Slot 906 ---
# Slot 906 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 907 ---
# Slot 907 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 908 ---
# Slot 908 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 909 ---
# Slot 909 SUCCESS: Proposer earned 0.3680 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 910 ---
# Slot 910 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 911 ---
# Slot 911 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 912 ---
# Slot 912 FAILED (NO SUPERMAJORITY): Proposer earned 0.0000 ETH. Attestations: 58/99 (Needed 66).
#
# --- Slot 913 ---
# Slot 913 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 914 ---
# Slot 914 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 915 ---
# Slot 915 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 916 ---
# Slot 916 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 917 ---
# Slot 917 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 918 ---
# Slot 918 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 919 ---
# Slot 919 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 920 ---
# Slot 920 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 91/99 (Needed 66).
#
# --- Slot 921 ---
# Slot 921 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 922 ---
# Slot 922 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 923 ---
# Slot 923 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 924 ---
# Slot 924 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 925 ---
# Slot 925 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 926 ---
# Slot 926 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 927 ---
# Slot 927 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 928 ---
# Slot 928 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 929 ---
# Slot 929 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 930 ---
# Slot 930 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 931 ---
# Slot 931 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 932 ---
# Slot 932 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 933 ---
# Slot 933 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 934 ---
# Slot 934 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 935 ---
# Slot 935 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 936 ---
# Slot 936 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 937 ---
# Slot 937 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 938 ---
# Slot 938 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 939 ---
# Slot 939 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 940 ---
# Slot 940 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 941 ---
# Slot 941 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 942 ---
# Slot 942 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 943 ---
# Slot 943 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 944 ---
# Slot 944 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 945 ---
# Slot 945 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 946 ---
# Slot 946 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 947 ---
# Slot 947 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 82/99 (Needed 66).
#
# --- Slot 948 ---
# Slot 948 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 949 ---
# Slot 949 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 91/99 (Needed 66).
#
# --- Slot 950 ---
# Slot 950 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 951 ---
# Slot 951 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 952 ---
# Slot 952 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 953 ---
# Slot 953 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 954 ---
# Slot 954 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 955 ---
# Slot 955 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 956 ---
# Slot 956 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 957 ---
# Slot 957 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 958 ---
# Slot 958 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 84/99 (Needed 66).
#
# --- Slot 959 ---
# Slot 959 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 960 ---
# Slot 960 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 961 ---
# Slot 961 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 962 ---
# Slot 962 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 963 ---
# Slot 963 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 964 ---
# Slot 964 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 965 ---
# Slot 965 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 966 ---
# Slot 966 SUCCESS: Proposer earned 0.3760 ETH. Attestations: 98/99 (Needed 66).
#
# --- Slot 967 ---
# Slot 967 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 968 ---
# Slot 968 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 83/99 (Needed 66).
#
# --- Slot 969 ---
# Slot 969 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 970 ---
# Slot 970 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 971 ---
# Slot 971 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 77/99 (Needed 66).
#
# --- Slot 972 ---
# Slot 972 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 973 ---
# Slot 973 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 78/99 (Needed 66).
#
# --- Slot 974 ---
# Slot 974 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 975 ---
# Slot 975 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 81/99 (Needed 66).
#
# --- Slot 976 ---
# Slot 976 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 977 ---
# Slot 977 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 978 ---
# Slot 978 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 80/99 (Needed 66).
#
# --- Slot 979 ---
# Slot 979 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 980 ---
# Slot 980 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 981 ---
# Slot 981 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 982 ---
# Slot 982 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 983 ---
# Slot 983 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 984 ---
# Slot 984 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 985 ---
# Slot 985 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 986 ---
# Slot 986 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 987 ---
# Slot 987 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 988 ---
# Slot 988 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 989 ---
# Slot 989 SUCCESS: Proposer earned 0.2400 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 990 ---
# Slot 990 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 991 ---
# Slot 991 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 992 ---
# Slot 992 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 993 ---
# Slot 993 SUCCESS: Proposer earned 0.3920 ETH. Attestations: 93/99 (Needed 66).
#
# --- Slot 994 ---
# Slot 994 SUCCESS: Proposer earned 0.3040 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 995 ---
# Slot 995 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 75/99 (Needed 66).
#
# --- Slot 996 ---
# Slot 996 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 86/99 (Needed 66).
#
# --- Slot 997 ---
# Slot 997 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 87/99 (Needed 66).
#
# --- Slot 998 ---
# Slot 998 SUCCESS: Proposer earned 0.3200 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 999 ---
# Slot 999 SUCCESS: Proposer earned 0.3120 ETH. Attestations: 99/99 (Needed 66).
#
# --- Slot 1000 ---
# Slot 1000 SUCCESS: Proposer earned 0.4000 ETH. Attestations: 81/99 (Needed 66).
#
# --- Simulation Results (Proposer Randomly Chooses Strategy) ---
# Total Slots Simulated: 1000
# Average MEV Earned Per Slot (by Proposer): 0.3146 ETH
# Average Effective Attestation Rate (across all Attesters): 95.53%
# Supermajority Attestation Success Rate: 98.80%
